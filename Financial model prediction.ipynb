# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.ensemble  import RandomForestClassifier

# %%
df = pd.read_excel("C:/Users/mudia/Downloads/Financial_inclusion_dataset.xlsx")

df.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns = categorical_columns[~categorical_columns.isin(['country', 'year', 'uniqueid', 'bank_account'])]
categorical_columns
# Out:
# Index(['location_type', 'cellphone_access', 'gender_of_respondent',
#        'relationship_with_head', 'marital_status', 'education_level',
#        'job_type'],
#       dtype='object')

# %%
label_encoder = LabelEncoder()

# Apply LabelEncoder to each categorical column and store the results in a new dataframe
encoded_df = df.copy()

for column in categorical_columns:
    encoded_df[column] = label_encoder.fit_transform(df[column])

encoded_df.head()
# Out:
#   country  year    uniqueid bank_account  location_type  cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes              0                 1
# 1   Kenya  2018  uniqueid_2           No              0                 0
# 2   Kenya  2018  uniqueid_3          Yes              1                 1
# 3   Kenya  2018  uniqueid_4           No              0                 1
# 4   Kenya  2018  uniqueid_5           No              1                 0
#
#    household_size  age_of_respondent  gender_of_respondent  \
# 0               3                 24                     0
# 1               5                 70                     0
# 2               5                 26                     1
# 3               5                 34                     0
# 4               8                 26                     1
#
#    relationship_with_head  marital_status  education_level  job_type
# 0                       5               2                3         9
# ...

# %%
#droppig the original categorical columns and concatenating the encoded columnsban
df.drop(columns=categorical_columns, inplace=True)
fin_df = pd.concat([df, encoded_df], axis=1)

# %%
df.head()
# Out:
#   country  year    uniqueid bank_account  household_size  age_of_respondent
# 0   Kenya  2018  uniqueid_1          Yes               3                 24
# 1   Kenya  2018  uniqueid_2           No               5                 70
# 2   Kenya  2018  uniqueid_3          Yes               5                 26
# 3   Kenya  2018  uniqueid_4           No               5                 34
# 4   Kenya  2018  uniqueid_5           No               8                 26

# %%
file_path = 'Financial_inclusion_saved.xlsx'
fin_df.to_excel(file_path, index=False)

# %%
fin_df.head()
# Out:
#   country  year    uniqueid bank_account  household_size  age_of_respondent  \
# 0   Kenya  2018  uniqueid_1          Yes               3                 24
# 1   Kenya  2018  uniqueid_2           No               5                 70
# 2   Kenya  2018  uniqueid_3          Yes               5                 26
# 3   Kenya  2018  uniqueid_4           No               5                 34
# 4   Kenya  2018  uniqueid_5           No               8                 26
#
#   country  year    uniqueid bank_account  location_type  cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes              0                 1
# 1   Kenya  2018  uniqueid_2           No              0                 0
# 2   Kenya  2018  uniqueid_3          Yes              1                 1
# 3   Kenya  2018  uniqueid_4           No              0                 1
# 4   Kenya  2018  uniqueid_5           No              1                 0
#
#    household_size  age_of_respondent  gender_of_respondent  \
# ...

# %%
x = fin_df.drop(columns=['country', 'year', 'uniqueid', 'bank_account'])
x.head()
x = x.loc[:, ~x.columns.duplicated()]
x.head()
# Out:
#    household_size  age_of_respondent  location_type  cellphone_access  \
# 0               3                 24              0                 1
# 1               5                 70              0                 0
# 2               5                 26              1                 1
# 3               5                 34              0                 1
# 4               8                 26              1                 0
#
#    gender_of_respondent  relationship_with_head  marital_status  \
# 0                     0                       5               2
# 1                     0                       1               4
# 2                     1                       3               3
# 3                     0                       1               2
# 4                     1                       0               3
#
#    education_level  job_type
# 0                3         9
# 1                0         4
# 2                5         9
# 3                2         3
# ...

# %%
fin_df = fin_df.loc[:, ~fin_df.columns.duplicated()]
y = fin_df.bank_account

y.map({'Yes': 1, 'No': 0})
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 23519    0
# 23520    0
# 23521    0
# 23522    0
# 23523    0
# Name: bank_account, Length: 23524, dtype: int64

# %%
y.value_counts()
# Out:
# bank_account
# No     20212
# Yes     3312
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
#Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(x_scaled,y, test_size= 0.20, random_state=0)

# %%
rf = RandomForestClassifier()

rf.fit(X_test, y_test)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9874601487778959
#               precision    recall  f1-score   support
#
#           No       0.99      1.00      0.99      4005
#          Yes       0.98      0.93      0.96       700
#
#     accuracy                           0.99      4705
#    macro avg       0.98      0.97      0.97      4705
# weighted avg       0.99      0.99      0.99      4705

# %%
# Saving the model
import pickle
pickle.dump(rf, open('model_saved', 'wb'))

# %%
#Loading the model 
loaded_model = pickle.load(open("C:/Users/mudia/OneDrive/Desktop/JJPF/model_saved", 'rb'))
